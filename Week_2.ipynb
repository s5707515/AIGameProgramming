# %% [markdown]
# <a href="https://colab.research.google.com/github/s5707515/AIGameProgramming/blob/main/Week_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPORTS

import math

import matplotlib.pyplot as plt
import numpy as np

#FUNCTIONS
def Sign(_x : float, _theta : float):
  _y = 0.0

  if _x > _theta:

    _y = 1.0

  elif _x < _theta:

    _y = -1.0

  return _y


def Step(_x : float, _theta : float):
  _y = 0.0

  if _x > _theta:

    _y = 1.0

  elif _x < _theta:

    _y = 0.0

  return _y

def Sigmoid(_x : float, _theta : float):
  _y = 0.0

  _y = 1 / (1 + math.e ** -(_x - _theta))

  return _y

def ReLU(_x : float, _theta : float):
  _y = 0.0

  if _x > _theta:

    _y = _x

  elif _x < _theta:

    _y = 0.0

  return y

def LeakyReLU(_x : float, _theta : float):
  _y = 0.0

  if _x > _theta:

    _y = _x

  elif _x < _theta:

    _y = 0.01 * _x

  return _y

def Linear(_x : float, _theta : float):

  _y = _x

  return _y

def Tanh(_x : float, _theta : float): #problem?
  _y = 0

  _y = (2 / (1 + math.e ** -(2* _x - _theta))+1)

  return _y

# %%
x = 0.5
y= 0.0
theta = 0.2

x = float(input("Enter the value of X: "))

y = Sign(x, theta)

print("The Sign Function output is: " + str(y))

y = Step(x, theta)

print("The Step Function output is: " + str(y))


y = Sigmoid(x, theta)

print("The Sigmoid Function output is: " + str(round(y,4)) + " (4dp)")
# Out:
# Enter the value of X: 7
# The Sign Function output is: 1.0
# The Step Function output is: 1.0
# The Sigmoid Function output is: 0.9989 (4dp)

# %% [markdown]
# ## **Line Graphs for functions:**

# %%
x_values = np.array([])
y_values = np.array([])


for i in range(-8,8):

  x_values = np.append(x_values, i)
  y_values = np.append(y_values, Sigmoid(i, theta))


plt.plot(x_values, y_values)

plt.xlabel("X Value")
plt.ylabel("Y Value")
plt.title("Sigmoid Function")
plt.show()

# %%
x_values = np.array([])
y_values = np.array([])


for i in range(-10,10):

  x_values = np.append(x_values, i/10)
  y_values = np.append(y_values, Step(i/10, theta))


plt.plot(x_values, y_values)

plt.xlabel("X Value")
plt.ylabel("Y Value")
plt.title("Step Function")
plt.show()

# %%
x_values = np.array([])
y_values = np.array([])


for i in range(-10,10):

  x_values = np.append(x_values, i/10)
  y_values = np.append(y_values, Sign(i/10, theta))


plt.plot(x_values, y_values)

plt.xlabel("X Value")
plt.ylabel("Y Value")
plt.title("Sign Function")
plt.show()

# %%
x_values = np.array([])
y_values = np.array([])


for i in range(-10,10):

  x_values = np.append(x_values, i)
  y_values = np.append(y_values, ReLU(i, theta))


plt.plot(x_values, y_values)

plt.xlabel("X Value")
plt.ylabel("Y Value")
plt.title("ReLU Function")
plt.show()

# %%
x_values = np.array([])
y_values = np.array([])


for i in range(-10,10):

  x_values = np.append(x_values, i)
  y_values = np.append(y_values, LeakyReLU(i, theta))


plt.plot(x_values, y_values)

plt.xlabel("X Value")
plt.ylabel("Y Value")
plt.title("Leaky ReLU Function")
plt.show()

# %%
x_values = np.array([])
y_values = np.array([])


for i in range(-10,10):

  x_values = np.append(x_values, i)
  y_values = np.append(y_values, Linear(i, theta))


plt.plot(x_values, y_values)

plt.xlabel("X Value")
plt.ylabel("Y Value")
plt.title("Linear Function")
plt.show()

# %%
x_values = np.array([])
y_values = np.array([])


for i in range(-80,80):

  x_values = np.append(x_values, i/10)
  y_values = np.append(y_values, Tanh(i/10, theta))


plt.plot(x_values, y_values)

plt.xlabel("X Value")
plt.ylabel("Y Value")
plt.title("Tanh Function")
plt.show()
